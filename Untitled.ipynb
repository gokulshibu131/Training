# %% [markdown]
# <a href="https://colab.research.google.com/github/gokulshibu131/Training/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("Enter the first no:"))
b=int(input("Enter the second no:"))
c=int(input("enter the third no:"))
print("Smallest number is:",min(a,b,c))
# Out:
# Enter the first no:10
# Enter the second no:28
# enter the third no:80
# Smallest number is: 10

# %%
n=int(input("Enter the no. of elements:"))
arr=[]
for i in range(n):
  x=int(input(f"Enter element {i+1}: ")) # Prompt for one element at a time
  arr.append(x)

print("Original array:",arr)
print("Reversed array:",arr[::-1])
# Out:
# Enter the no. of elements:10
# Enter the element:5
# Orginal array: [5]
# Reversed array: [5]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1132/975888255.py in <cell line: 0>()
#       2 arr=[]
#       3 for i in range(n):
# ----> 4   x=int(input("Enter the element:"))
#       5   arr.append(x)
#       6   print("Orginal array:",arr)
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
arr=[]
n=int(input("enter array limit:"))
for i in range(n):
  arr.append(int(input("Enter a no:")))
  print("Sum of elements:",sum(arr))
# Out:
# enter array limit:5
# Enter a no:6
# Sum of elements: 6
